# %% [markdown]
# ![File-1-Cleaning-and-Data-Processing.png](attachment:File-1-Cleaning-and-Data-Processing.png)

# %% [markdown]
# **This project's aim**, is to explore the world of Natural Language Processing (NLP) by building what is known as a Sentiment Analysis Model. A sentiment analysis model is a model that analyses a given piece of text and predicts whether this piece of text expresses positive or negative sentiment.
#
# **Cleaning and processing** Twitter data using NLP is an essential task for extracting meaningful insights from the vast and dynamic world of social media. In this process, raw tweet data is refined through various steps such as deduplication, removal of irrelevant information.

# %% [markdown]
# <div style="text-align: center; background-color: #856ff8; padding: 10px;">
#     <h2 style="font-weight: bold;">OUTLINE</h2>
# </div>

# %% [markdown]
# - Importing Various Modules
# - Loading Dataset
# - Trim Data
# - Data Processing
# - Data Cleaning
#   - HTML Decoding
#   - URL Links
#   - Mentions
#   - Hastags
#   - Data Cleaning Function
# - Save Dataframe to CSV File

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">IMPORTING VARIOUS MODULES</h2>
# </div>

# %%
import pandas as pd
import numpy as np

import re
import html

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from nltk.tokenize import TreebankWordTokenizer

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">LOADING DATASET</h2>
# </div>

# %%
# Reading the dataset with no columns titles and with latin encoding 
twitter_data_raw = pd.read_csv('sentiment140.csv', encoding = "ISO-8859-1", header=None)

# %%
# As the data has no column titles, we will add our own
twitter_data_raw.columns = ['sentiment', 'id', 'date', 'query_string', 'user', 'text']

# %%
# Show the first 5 rows of the dataframe.
twitter_data_raw.head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_ae5c2_row0_col0, #T_ae5c2_row0_col1, #T_ae5c2_row0_col2, #T_ae5c2_row0_col3, #T_ae5c2_row0_col4, #T_ae5c2_row0_col5, #T_ae5c2_row1_col0, #T_ae5c2_row1_col1, #T_ae5c2_row1_col2, #T_ae5c2_row1_col3, #T_ae5c2_row1_col4, #T_ae5c2_row1_col5, #T_ae5c2_row2_col0, #T_ae5c2_row2_col1, #T_ae5c2_row2_col2, #T_ae5c2_row2_col3, #T_ae5c2_row2_col4, #T_ae5c2_row2_col5, #T_ae5c2_row3_col0, #T_ae5c2_row3_col1, #T_ae5c2_row3_col2, #T_ae5c2_row3_col3, #T_ae5c2_row3_col4, #T_ae5c2_row3_col5, #T_ae5c2_row4_col0, #T_ae5c2_row4_col1, #T_ae5c2_row4_col2, #T_ae5c2_row4_col3, #T_ae5c2_row4_col4, #T_ae5c2_row4_col5 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_ae5c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae5c2_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_ae5c2_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_ae5c2_level0_col2" class="col_heading level0 col2" >date</th>
#       <th id="T_ae5c2_level0_col3" class="col_heading level0 col3" >query_string</th>
#       <th id="T_ae5c2_level0_col4" class="col_heading level0 col4" >user</th>
#       <th id="T_ae5c2_level0_col5" class="col_heading level0 col5" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae5c2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae5c2_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ae5c2_row0_col1" class="data row0 col1" >1467810369</td>
#       <td id="T_ae5c2_row0_col2" class="data row0 col2" >Mon Apr 06 22:19:45 PDT 2009</td>
#       <td id="T_ae5c2_row0_col3" class="data row0 col3" >NO_QUERY</td>
#       <td id="T_ae5c2_row0_col4" class="data row0 col4" >_TheSpecialOne_</td>
#       <td id="T_ae5c2_row0_col5" class="data row0 col5" >@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D</td>
#     </tr>
#     <tr>
#       <th id="T_ae5c2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae5c2_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_ae5c2_row1_col1" class="data row1 col1" >1467810672</td>
#       <td id="T_ae5c2_row1_col2" class="data row1 col2" >Mon Apr 06 22:19:49 PDT 2009</td>
#       <td id="T_ae5c2_row1_col3" class="data row1 col3" >NO_QUERY</td>
#       <td id="T_ae5c2_row1_col4" class="data row1 col4" >scotthamilton</td>
#       <td id="T_ae5c2_row1_col5" class="data row1 col5" >is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!</td>
#     </tr>
#     <tr>
#       <th id="T_ae5c2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ae5c2_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_ae5c2_row2_col1" class="data row2 col1" >1467810917</td>
#       <td id="T_ae5c2_row2_col2" class="data row2 col2" >Mon Apr 06 22:19:53 PDT 2009</td>
#       <td id="T_ae5c2_row2_col3" class="data row2 col3" >NO_QUERY</td>
#       <td id="T_ae5c2_row2_col4" class="data row2 col4" >mattycus</td>
#       <td id="T_ae5c2_row2_col5" class="data row2 col5" >@Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds</td>
#     </tr>
#     <tr>
#       <th id="T_ae5c2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ae5c2_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_ae5c2_row3_col1" class="data row3 col1" >1467811184</td>
#       <td id="T_ae5c2_row3_col2" class="data row3 col2" >Mon Apr 06 22:19:57 PDT 2009</td>
#       <td id="T_ae5c2_row3_col3" class="data row3 col3" >NO_QUERY</td>
#       <td id="T_ae5c2_row3_col4" class="data row3 col4" >ElleCTF</td>
#       <td id="T_ae5c2_row3_col5" class="data row3 col5" >my whole body feels itchy and like its on fire </td>
#     </tr>
#     <tr>
#       <th id="T_ae5c2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ae5c2_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_ae5c2_row4_col1" class="data row4 col1" >1467811193</td>
#       <td id="T_ae5c2_row4_col2" class="data row4 col2" >Mon Apr 06 22:19:57 PDT 2009</td>
#       <td id="T_ae5c2_row4_col3" class="data row4 col3" >NO_QUERY</td>
#       <td id="T_ae5c2_row4_col4" class="data row4 col4" >Karoli</td>
#       <td id="T_ae5c2_row4_col5" class="data row4 col5" >@nationwideclass no, it's not behaving at all. i'm mad. why am i here? because I can't see you all over there. </td>
#     </tr>
#   </tbody>
# </table>

# %%
# Print bottom 5 rows in the dataframe.
twitter_data_raw.tail().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_09671_row0_col0, #T_09671_row0_col1, #T_09671_row0_col2, #T_09671_row0_col3, #T_09671_row0_col4, #T_09671_row0_col5, #T_09671_row1_col0, #T_09671_row1_col1, #T_09671_row1_col2, #T_09671_row1_col3, #T_09671_row1_col4, #T_09671_row1_col5, #T_09671_row2_col0, #T_09671_row2_col1, #T_09671_row2_col2, #T_09671_row2_col3, #T_09671_row2_col4, #T_09671_row2_col5, #T_09671_row3_col0, #T_09671_row3_col1, #T_09671_row3_col2, #T_09671_row3_col3, #T_09671_row3_col4, #T_09671_row3_col5, #T_09671_row4_col0, #T_09671_row4_col1, #T_09671_row4_col2, #T_09671_row4_col3, #T_09671_row4_col4, #T_09671_row4_col5 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_09671">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09671_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_09671_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_09671_level0_col2" class="col_heading level0 col2" >date</th>
#       <th id="T_09671_level0_col3" class="col_heading level0 col3" >query_string</th>
#       <th id="T_09671_level0_col4" class="col_heading level0 col4" >user</th>
#       <th id="T_09671_level0_col5" class="col_heading level0 col5" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09671_level0_row0" class="row_heading level0 row0" >1599995</th>
#       <td id="T_09671_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_09671_row0_col1" class="data row0 col1" >2193601966</td>
#       <td id="T_09671_row0_col2" class="data row0 col2" >Tue Jun 16 08:40:49 PDT 2009</td>
#       <td id="T_09671_row0_col3" class="data row0 col3" >NO_QUERY</td>
#       <td id="T_09671_row0_col4" class="data row0 col4" >AmandaMarie1028</td>
#       <td id="T_09671_row0_col5" class="data row0 col5" >Just woke up. Having no school is the best feeling ever </td>
#     </tr>
#     <tr>
#       <th id="T_09671_level0_row1" class="row_heading level0 row1" >1599996</th>
#       <td id="T_09671_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_09671_row1_col1" class="data row1 col1" >2193601969</td>
#       <td id="T_09671_row1_col2" class="data row1 col2" >Tue Jun 16 08:40:49 PDT 2009</td>
#       <td id="T_09671_row1_col3" class="data row1 col3" >NO_QUERY</td>
#       <td id="T_09671_row1_col4" class="data row1 col4" >TheWDBoards</td>
#       <td id="T_09671_row1_col5" class="data row1 col5" >TheWDB.com - Very cool to hear old Walt interviews!  â« http://blip.fm/~8bmta</td>
#     </tr>
#     <tr>
#       <th id="T_09671_level0_row2" class="row_heading level0 row2" >1599997</th>
#       <td id="T_09671_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_09671_row2_col1" class="data row2 col1" >2193601991</td>
#       <td id="T_09671_row2_col2" class="data row2 col2" >Tue Jun 16 08:40:49 PDT 2009</td>
#       <td id="T_09671_row2_col3" class="data row2 col3" >NO_QUERY</td>
#       <td id="T_09671_row2_col4" class="data row2 col4" >bpbabe</td>
#       <td id="T_09671_row2_col5" class="data row2 col5" >Are you ready for your MoJo Makeover? Ask me for details </td>
#     </tr>
#     <tr>
#       <th id="T_09671_level0_row3" class="row_heading level0 row3" >1599998</th>
#       <td id="T_09671_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_09671_row3_col1" class="data row3 col1" >2193602064</td>
#       <td id="T_09671_row3_col2" class="data row3 col2" >Tue Jun 16 08:40:49 PDT 2009</td>
#       <td id="T_09671_row3_col3" class="data row3 col3" >NO_QUERY</td>
#       <td id="T_09671_row3_col4" class="data row3 col4" >tinydiamondz</td>
#       <td id="T_09671_row3_col5" class="data row3 col5" >Happy 38th Birthday to my boo of alll time!!! Tupac Amaru Shakur </td>
#     </tr>
#     <tr>
#       <th id="T_09671_level0_row4" class="row_heading level0 row4" >1599999</th>
#       <td id="T_09671_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_09671_row4_col1" class="data row4 col1" >2193602129</td>
#       <td id="T_09671_row4_col2" class="data row4 col2" >Tue Jun 16 08:40:50 PDT 2009</td>
#       <td id="T_09671_row4_col3" class="data row4 col3" >NO_QUERY</td>
#       <td id="T_09671_row4_col4" class="data row4 col4" >RyanTrevMorris</td>
#       <td id="T_09671_row4_col5" class="data row4 col5" >happy #charitytuesday @theNSPCC @SparksCharity @SpeakingUpH4H </td>
#     </tr>
#   </tbody>
# </table>

# %%
# Print the shape of the DataFrame
print("The shape of data frame:", twitter_data_raw.shape)
# Print the length (number of rows) of the DataFrame
print("Number of Rows in the dataframe:", len(twitter_data_raw))
# Print the number of columns in the DataFrame
print("Number of Columns in the dataframe:", len(twitter_data_raw.columns))
# Out:
# The shape of data frame: (1600000, 6)
# Number of Rows in the dataframe: 1600000
# Number of Columns in the dataframe: 6

# %%
twitter_data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   sentiment     1600000 non-null  int64
#  1   id            1600000 non-null  int64
#  2   date          1600000 non-null  object
#  3   query_string  1600000 non-null  object
#  4   user          1600000 non-null  object
#  5   text          1600000 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB

# %%
sentiment_counts = twitter_data_raw['sentiment'].value_counts()

# %%
# Print the counts and sentiment labels
print("Sentiment Distribution:")
print("Negative (0):", sentiment_counts[0])
print("Positive (4):", sentiment_counts[4])
# Out:
# Sentiment Distribution:
# Negative (0): 800000
# Positive (4): 800000

# %%
# Calculate and print the percentage breakdown
total_tweets = len(twitter_data_raw)
percentage_negative = (sentiment_counts[0] / total_tweets) * 100
percentage_positive = (sentiment_counts[4] / total_tweets) * 100

# %%
print("\nPercentage Breakdown:")
print("Negative: {:.2f}%".format(percentage_negative))
print("Positive: {:.2f}%".format(percentage_positive))
# Out:
# Percentage Breakdown:
# Negative: 50.00%
# Positive: 50.00%

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">TRIM DATA</h2>
# </div>

# %%
# Seperating positive and negative rows
twitter_data_raw_pos = twitter_data_raw[twitter_data_raw['sentiment'] == 4]
twitter_data_raw_neg = twitter_data_raw[twitter_data_raw['sentiment'] == 0]

# %%
# Only retaining a fraction of the data from each output group using sample
frac = 1/4  # You can adjust this fraction as needed
twitter_data_raw_pos = twitter_data_raw_pos.sample(frac=frac, random_state=42)
twitter_data_raw_neg = twitter_data_raw_neg.sample(frac=frac, random_state=42)

# %%
# Concatenating both positive and negative groups and storing them back into a single dataframe
twitter_data_trim = pd.concat([twitter_data_raw_pos, twitter_data_raw_neg])

# %%
# Display lengths
print(len(twitter_data_raw_pos), len(twitter_data_raw_neg))
print(len(twitter_data_trim))
# Out:
# 200000 200000
# 400000

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">DATA PROCESSING</h2>
# </div>

# %%
twitter_data_trim['Preclean_Length'] = twitter_data_trim['text'].apply(lambda x: len(x))

# %%
twitter_data_trim.drop(['id', 'date', 'query_string', 'user'], axis=1, inplace=True)

# %%
twitter_data_trim.head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_f58f7_row0_col0, #T_f58f7_row0_col1, #T_f58f7_row0_col2, #T_f58f7_row1_col0, #T_f58f7_row1_col1, #T_f58f7_row1_col2, #T_f58f7_row2_col0, #T_f58f7_row2_col1, #T_f58f7_row2_col2, #T_f58f7_row3_col0, #T_f58f7_row3_col1, #T_f58f7_row3_col2, #T_f58f7_row4_col0, #T_f58f7_row4_col1, #T_f58f7_row4_col2 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_f58f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f58f7_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_f58f7_level0_col1" class="col_heading level0 col1" >text</th>
#       <th id="T_f58f7_level0_col2" class="col_heading level0 col2" >Preclean_Length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f58f7_level0_row0" class="row_heading level0 row0" >1012188</th>
#       <td id="T_f58f7_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_f58f7_row0_col1" class="data row0 col1" >Is lookin 4ward to a long weekend  really dont want to go to work 2day tho =[ x</td>
#       <td id="T_f58f7_row0_col2" class="data row0 col2" >79</td>
#     </tr>
#     <tr>
#       <th id="T_f58f7_level0_row1" class="row_heading level0 row1" >1099036</th>
#       <td id="T_f58f7_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_f58f7_row1_col1" class="data row1 col1" >#myweakness  Is music and i live to meet the people who make it </td>
#       <td id="T_f58f7_row1_col2" class="data row1 col2" >64</td>
#     </tr>
#     <tr>
#       <th id="T_f58f7_level0_row2" class="row_heading level0 row2" >1275978</th>
#       <td id="T_f58f7_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_f58f7_row2_col1" class="data row2 col1" >figured out the Internet on my new iPod </td>
#       <td id="T_f58f7_row2_col2" class="data row2 col2" >40</td>
#     </tr>
#     <tr>
#       <th id="T_f58f7_level0_row3" class="row_heading level0 row3" >1388988</th>
#       <td id="T_f58f7_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_f58f7_row3_col1" class="data row3 col1" >@hillsongunited can't wait to worship with you guys tonight. it'll be so much fun </td>
#       <td id="T_f58f7_row3_col2" class="data row3 col2" >82</td>
#     </tr>
#     <tr>
#       <th id="T_f58f7_level0_row4" class="row_heading level0 row4" >938859</th>
#       <td id="T_f58f7_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_f58f7_row4_col1" class="data row4 col1" >@sillybeggar Congrats James !! I'm sure the book is going to be a huge success </td>
#       <td id="T_f58f7_row4_col2" class="data row4 col2" >79</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Set the style
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
sns.distplot(twitter_data_trim['Preclean_Length'], kde=False, color='skyblue', hist_kws=dict(edgecolor="k", linewidth=2))

# Add labels and title
plt.title('Distribution of Preclean_Length', fontsize=16)
plt.xlabel('Preclean_Length', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# Set the style
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))
sns.boxplot(y='Preclean_Length', data=twitter_data_trim, color='skyblue', width=0.3)

# Add labels and title
plt.title('Boxplot of Preclean_Length', fontsize=16)
plt.ylabel('Preclean_Length', fontsize=14)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
twitter_data_trim[twitter_data_trim['Preclean_Length']>140]
# Out:
#          sentiment                                               text  \
# 1029581          4  Night all. Only 5 hours of sleep last night &a...
# 1185915          4  @JonathanRKnight for realz! Safe travels- hope...
# 1440623          4  Just came back from watching my brothers play ...
# 1337319          4  Everybody check out @ItsTyraB's song &quot;You...
# 1427762          4  A squirrel says to a tree: &quot;I did not sto...
# ...            ...                                                ...
# 230645           0  @ivaleriei I love that movie, never been to al...
# 93225            0  @JewelStaite &lt;small voice&gt;I sometimes si...
# 218260           0  @Talsiach I know. Weird...And I've &quot;lost&...
# 446306           0  i've possibily ruined cheese forever for my pa...
# 342174           0  I just want to scream &quot;DON'T DO IT&quot; ...
#
#          Preclean_Length
# 1029581              143
# 1185915              141
# 1440623              141
# 1337319              161
# 1427762              141
# ...                  ...
# 230645               146
# 93225                151
# 218260               143
# 446306               142
# 342174               148
#
# [4397 rows x 3 columns]

# %% [markdown]
# Hence, some tweets are more than 140 characters long. We need to clean the data.

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">DATA CLEANING</h2>
# </div>

# %% [markdown]
# <br>
# <span style="color: yellow; background-color: black; font-weight: bold; padding: 5px; font-size: 24px;"> HTML Decoding </span>
# </br>

# %%
twitter_data_trim['text'][248]
# Out:
# 'Missing My BFF  watching home and away it reminds me of her and me  we &lt;3 It. shout out to u courts'

# %%
tweet = html.unescape(twitter_data_trim['text'][248])

# %%
tweet
# Out:
# 'Missing My BFF  watching home and away it reminds me of her and me  we <3 It. shout out to u courts'

# %% [markdown]
# <br>
# <span style="color: yellow; background-color: black; font-weight: bold; padding: 5px; font-size: 24px;"> URL Links </span>
# </br>

# %%
twitter_data_trim['text'][0]
# Out:
# "@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D"

# %%
re.sub('https?://[A-Za-z0-9./]+','',twitter_data_trim['text'][0])
# Out:
# "@switchfoot  - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D"

# %% [markdown]
# <br>
# <span style="color: yellow; background-color: black; font-weight: bold; padding: 5px; font-size: 24px;"> Mentions </span>
# </br>

# %%
twitter_data_trim['text'][0]
# Out:
# "@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D"

# %%
re.sub(r'@[A-Za-z0-9]+','', twitter_data_trim['text'][0])
# Out:
# " http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D"

# %% [markdown]
# <br>
# <span style="color: yellow; background-color: black; font-weight: bold; padding: 5px; font-size: 24px;"> Hastags </span>
# </br>

# %%
twitter_data_trim['text'][175]
# Out:
# "@machineplay I'm so sorry you're having to go through this. Again.  #therapyfail"

# %%
re.sub("[^a-zA-Z]", " ", twitter_data_trim['text'][175])
# Out:
# ' machineplay I m so sorry you re having to go through this  Again    therapyfail'

# %% [markdown]
# <br>
# <span style="color: lightblue; background-color: black; font-weight: bold; padding: 5px; font-size: 32px;"> Data Cleaning Function </span>
# </br>

# %%
token = TreebankWordTokenizer()

# %%
mentions = r'@[A-Za-z0-9]+'
url_https = 'https?://[A-Za-z0-9./]+'
url_www = r'www.[^ ]+'

# %%
word = "I am a  master isn't"
lists = token.tokenize(word)
print(" ".join(lists).strip())
# Out:
# I am a master is n't

# %%
negations = {"isn't":"is not", "aren't":"are not", "wasn't":"was not", "weren't":"were not",
             "haven't":"have not","hasn't":"has not","hadn't":"had not","won't":"will not",
             "wouldn't":"would not", "don't":"do not", "doesn't":"does not","didn't":"did not",
             "can't":"can not","couldn't":"could not","shouldn't":"should not","mightn't":"might not",
             "mustn't":"must not"
            }

# %%
for a,b in negations.items():
    if a in word:
        word = word.replace(a, b)

# %%
word
# Out:
# 'I am a  master is not'

# %%
def tweet_cleaning(text):
    text = html.unescape(text)
    text = re.sub(mentions, '', text)
    text = re.sub(url_https, '', text)
    text = re.sub(url_www, '', text)
    text = text.lower()
    for a, b in negations.items():
        if a in text:
            text = text.replace(a,b)
    #Removing characters except letters
    text = re.sub("[^a-zA-Z]", " ", text)
    #Removing unnecessary white spaces using tokenizer
    word_list = token.tokenize(text)
    text = " ".join(word_list).strip()
    return text

# %%
twitter_data_trim['text'] = twitter_data_trim['text'].apply(lambda x: tweet_cleaning(x))

# %%
twitter_data_trim.head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_7a9dd_row0_col0, #T_7a9dd_row0_col1, #T_7a9dd_row0_col2, #T_7a9dd_row1_col0, #T_7a9dd_row1_col1, #T_7a9dd_row1_col2, #T_7a9dd_row2_col0, #T_7a9dd_row2_col1, #T_7a9dd_row2_col2, #T_7a9dd_row3_col0, #T_7a9dd_row3_col1, #T_7a9dd_row3_col2, #T_7a9dd_row4_col0, #T_7a9dd_row4_col1, #T_7a9dd_row4_col2 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_7a9dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a9dd_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_7a9dd_level0_col1" class="col_heading level0 col1" >text</th>
#       <th id="T_7a9dd_level0_col2" class="col_heading level0 col2" >Preclean_Length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a9dd_level0_row0" class="row_heading level0 row0" >1012188</th>
#       <td id="T_7a9dd_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_7a9dd_row0_col1" class="data row0 col1" >is lookin ward to a long weekend really dont want to go to work day tho x</td>
#       <td id="T_7a9dd_row0_col2" class="data row0 col2" >79</td>
#     </tr>
#     <tr>
#       <th id="T_7a9dd_level0_row1" class="row_heading level0 row1" >1099036</th>
#       <td id="T_7a9dd_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_7a9dd_row1_col1" class="data row1 col1" >myweakness is music and i live to meet the people who make it</td>
#       <td id="T_7a9dd_row1_col2" class="data row1 col2" >64</td>
#     </tr>
#     <tr>
#       <th id="T_7a9dd_level0_row2" class="row_heading level0 row2" >1275978</th>
#       <td id="T_7a9dd_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_7a9dd_row2_col1" class="data row2 col1" >figured out the internet on my new ipod</td>
#       <td id="T_7a9dd_row2_col2" class="data row2 col2" >40</td>
#     </tr>
#     <tr>
#       <th id="T_7a9dd_level0_row3" class="row_heading level0 row3" >1388988</th>
#       <td id="T_7a9dd_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_7a9dd_row3_col1" class="data row3 col1" >can not wait to worship with you guys tonight it ll be so much fun</td>
#       <td id="T_7a9dd_row3_col2" class="data row3 col2" >82</td>
#     </tr>
#     <tr>
#       <th id="T_7a9dd_level0_row4" class="row_heading level0 row4" >938859</th>
#       <td id="T_7a9dd_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_7a9dd_row4_col1" class="data row4 col1" >congrats james i m sure the book is going to be a huge success</td>
#       <td id="T_7a9dd_row4_col2" class="data row4 col2" >79</td>
#     </tr>
#   </tbody>
# </table>

# %%
twitter_data_trim.drop(['Preclean_Length'], axis=1, inplace=True)

# %%
twitter_data_trim.head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_88c6f_row0_col0, #T_88c6f_row0_col1, #T_88c6f_row1_col0, #T_88c6f_row1_col1, #T_88c6f_row2_col0, #T_88c6f_row2_col1, #T_88c6f_row3_col0, #T_88c6f_row3_col1, #T_88c6f_row4_col0, #T_88c6f_row4_col1 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_88c6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88c6f_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_88c6f_level0_col1" class="col_heading level0 col1" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88c6f_level0_row0" class="row_heading level0 row0" >1012188</th>
#       <td id="T_88c6f_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_88c6f_row0_col1" class="data row0 col1" >is lookin ward to a long weekend really dont want to go to work day tho x</td>
#     </tr>
#     <tr>
#       <th id="T_88c6f_level0_row1" class="row_heading level0 row1" >1099036</th>
#       <td id="T_88c6f_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_88c6f_row1_col1" class="data row1 col1" >myweakness is music and i live to meet the people who make it</td>
#     </tr>
#     <tr>
#       <th id="T_88c6f_level0_row2" class="row_heading level0 row2" >1275978</th>
#       <td id="T_88c6f_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_88c6f_row2_col1" class="data row2 col1" >figured out the internet on my new ipod</td>
#     </tr>
#     <tr>
#       <th id="T_88c6f_level0_row3" class="row_heading level0 row3" >1388988</th>
#       <td id="T_88c6f_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_88c6f_row3_col1" class="data row3 col1" >can not wait to worship with you guys tonight it ll be so much fun</td>
#     </tr>
#     <tr>
#       <th id="T_88c6f_level0_row4" class="row_heading level0 row4" >938859</th>
#       <td id="T_88c6f_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_88c6f_row4_col1" class="data row4 col1" >congrats james i m sure the book is going to be a huge success</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">SAVING THE DATASET</h2>
# </div>

# %%
output_file_path = 'twitter_sentiment_data_cleaned.csv'

# %%
# Save the DataFrame to a CSV file
twitter_data_trim.to_csv(output_file_path, index=False)

# %%
print("DataFrame saved to:", output_file_path)
# Out:
# DataFrame saved to: twitter_sentiment_data_cleaned.csv
