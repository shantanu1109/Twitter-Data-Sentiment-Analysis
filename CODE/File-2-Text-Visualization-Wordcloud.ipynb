# %% [markdown]
# ![File-2-Data-Visualization.png](attachment:File-2-Data-Visualization.png)

# %% [markdown]
# **Text visualization** in Natural Language Processing (NLP) involves creating visual representations of textual data to gain insights, explore patterns, and communicate findings.

# %% [markdown]
# <div style="text-align: center; background-color: #856ff8; padding: 10px;">
#     <h2 style="font-weight: bold;">OUTLINE</h2>
# </div>

# %% [markdown]
# - Importing Various Modules
# - Loading Dataset
# - Dropping Null Values
# - Text Visualization
#   - Negative Tweets
#   - Positive Tweets
# - Data Transformation
# - Save Dataframe to CSV File

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">IMPORTING VARIOUS MODULES</h2>
# </div>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from wordcloud import WordCloud, STOPWORDS

from sklearn.feature_extraction.text import CountVectorizer

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">LOADING DATASET</h2>
# </div>

# %%
# Reading the dataset with no columns titles and with latin encoding 
twitter_data = pd.read_csv('twitter_sentiment_data_cleaned.csv', encoding = "ISO-8859-1")

# %%
# As the data has no column titles, we will add our own
twitter_data.columns = ['sentiment', 'text']

# %%
# Show the first 5 rows of the dataframe.
twitter_data.head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_fa84d_row0_col0, #T_fa84d_row0_col1, #T_fa84d_row1_col0, #T_fa84d_row1_col1, #T_fa84d_row2_col0, #T_fa84d_row2_col1, #T_fa84d_row3_col0, #T_fa84d_row3_col1, #T_fa84d_row4_col0, #T_fa84d_row4_col1 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_fa84d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa84d_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_fa84d_level0_col1" class="col_heading level0 col1" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa84d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa84d_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_fa84d_row0_col1" class="data row0 col1" >is lookin ward to a long weekend really dont want to go to work day tho x</td>
#     </tr>
#     <tr>
#       <th id="T_fa84d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa84d_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_fa84d_row1_col1" class="data row1 col1" >myweakness is music and i live to meet the people who make it</td>
#     </tr>
#     <tr>
#       <th id="T_fa84d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa84d_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_fa84d_row2_col1" class="data row2 col1" >figured out the internet on my new ipod</td>
#     </tr>
#     <tr>
#       <th id="T_fa84d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa84d_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_fa84d_row3_col1" class="data row3 col1" >can not wait to worship with you guys tonight it ll be so much fun</td>
#     </tr>
#     <tr>
#       <th id="T_fa84d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa84d_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_fa84d_row4_col1" class="data row4 col1" >congrats james i m sure the book is going to be a huge success</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Print bottom 5 rows in the dataframe.
twitter_data.tail().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_c7676_row0_col0, #T_c7676_row0_col1, #T_c7676_row1_col0, #T_c7676_row1_col1, #T_c7676_row2_col0, #T_c7676_row2_col1, #T_c7676_row3_col0, #T_c7676_row3_col1, #T_c7676_row4_col0, #T_c7676_row4_col1 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_c7676">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7676_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_c7676_level0_col1" class="col_heading level0 col1" >text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7676_level0_row0" class="row_heading level0 row0" >399995</th>
#       <td id="T_c7676_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c7676_row0_col1" class="data row0 col1" >that is he does not know i tweet and i would like keep it that way sorry bad wife</td>
#     </tr>
#     <tr>
#       <th id="T_c7676_level0_row1" class="row_heading level0 row1" >399996</th>
#       <td id="T_c7676_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_c7676_row1_col1" class="data row1 col1" >huh what</td>
#     </tr>
#     <tr>
#       <th id="T_c7676_level0_row2" class="row_heading level0 row2" >399997</th>
#       <td id="T_c7676_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_c7676_row2_col1" class="data row2 col1" >only thing is im broke</td>
#     </tr>
#     <tr>
#       <th id="T_c7676_level0_row3" class="row_heading level0 row3" >399998</th>
#       <td id="T_c7676_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_c7676_row3_col1" class="data row3 col1" >wish i could work from home today nothing will be going on here</td>
#     </tr>
#     <tr>
#       <th id="T_c7676_level0_row4" class="row_heading level0 row4" >399999</th>
#       <td id="T_c7676_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_c7676_row4_col1" class="data row4 col1" >i miss you too i was so worried well today s my last day of school b the break glad u feel better love you</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Print the shape of the DataFrame
print("The shape of data frame:", twitter_data.shape)
# Print the length (number of rows) of the DataFrame
print("Number of Rows in the dataframe:", len(twitter_data))
# Print the number of columns in the DataFrame
print("Number of Columns in the dataframe:", len(twitter_data.columns))
# Out:
# The shape of data frame: (400000, 2)
# Number of Rows in the dataframe: 400000
# Number of Columns in the dataframe: 2

# %%
twitter_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400000 entries, 0 to 399999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   sentiment  400000 non-null  int64
#  1   text       399187 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 6.1+ MB

# %%
# Count the number of null values.
null_values_by_column = twitter_data.isna().sum()
print(null_values_by_column)
# Out:
# sentiment      0
# text         813
# dtype: int64

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">DROPPING NULL VALUES</h2>
# </div>

# %%
cols = ['sentiment', 'id', 'date', 'query_string', 'user', 'text']
twitter_data_original = pd.read_csv('sentiment140.csv', header=None, encoding = "ISO-8859-1", names=cols)

# %%
# Seperating positive and negative rows
twitter_data_original_pos = twitter_data_original[twitter_data_original['sentiment'] == 4]
twitter_data_original_neg = twitter_data_original[twitter_data_original['sentiment'] == 0]

# %%
# Only retaining a fraction of the data from each output group using sample
frac = 1/4  # You can adjust this fraction as needed
twitter_data_original_pos = twitter_data_original_pos.sample(frac=frac, random_state=42)
twitter_data_original_neg = twitter_data_original_neg.sample(frac=frac, random_state=42)

# %%
# Concatenating both positive and negative groups and storing them back into a single dataframe
twitter_data_trim = pd.concat([twitter_data_original_pos, twitter_data_original_neg])

# %%
# Display lengths
print(len(twitter_data_original_pos), len(twitter_data_original_neg))
print(len(twitter_data_trim))
# Out:
# 200000 200000
# 400000

# %%
twitter_data_original.iloc[twitter_data[twitter_data['text'].isnull()].index].head()
# Out:
#       sentiment          id                          date query_string  \
# 88            0  1467835198  Mon Apr 06 22:26:08 PDT 2009     NO_QUERY
# 437           0  1467923370  Mon Apr 06 22:49:57 PDT 2009     NO_QUERY
# 441           0  1467924690  Mon Apr 06 22:50:17 PDT 2009     NO_QUERY
# 1983          0  1468278742  Tue Apr 07 00:42:38 PDT 2009     NO_QUERY
# 2109          0  1468305783  Tue Apr 07 00:52:07 PDT 2009     NO_QUERY
#
#                  user                                               text
# 88      ItsBrigittaYo                   why is it always the fat ones?!
# 437     xmattxwalkerx  just woke up from the most vivid, sketchy, not...
# 441           FlyRice          Good GOD they ruined my belly button!!!
# 1983      DreamCharon                          4 am insomnia is a BITCH
# 2109  TattooedGumball  Today I got2do shopping 4easter! &lt;3 Malachi...

# %% [markdown]
# Hence, because of data cleaning, some tweets now have NULL values. This is because those tweets comprised only of mentions or url links. Hence, these Null values must be dropped.

# %%
twitter_data.dropna(inplace=True)

# %%
twitter_data['sentiment'] = twitter_data['sentiment'].map({0:0,4:1})

# %%
twitter_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 399187 entries, 0 to 399999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   sentiment  399187 non-null  int64
#  1   text       399187 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 9.1+ MB

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">TEXT VISUALIZATION</h2>
# </div>

# %%
stopwords = set(STOPWORDS)

# %%
# Generate WordCloud with custom parameters
wordcloud = WordCloud(
    background_color='black',
    stopwords=stopwords,
    max_font_size=60,
    random_state=42,
    colormap='viridis',  # You can change the colormap
    contour_color='steelblue',  # Color of the wordcloud border
    contour_width=2,  # Width of the wordcloud border
    width=800,
    height=400,
).generate(str(twitter_data['text']))

# %%
# Plot the WordCloud
fig = plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud', fontsize=16)
plt.axis('off')
plt.show()

# %% [markdown]
# <br>
# <span style="color: yellow; background-color: black; font-weight: bold; padding: 5px; font-size: 32px;"> Negative Tweets </span>
# </br>

# %% [markdown]
# This word cloud consists of the words which have the highest frequency among all the tweets, positive and negative both.

# %%
negative_tweets = twitter_data[twitter_data['sentiment']==0]

# Concatenate negative tweets
neg_tweet = ' '.join(negative_tweets['text'].astype(str))

# Generate WordCloud with custom parameters
neg_wordcloud = WordCloud(
    width=1600,
    height=800,
    max_font_size=200,
    background_color='black',
    colormap='viridis',  # You can change the colormap
    contour_color='steelblue',  # Color of the wordcloud border
    contour_width=2,  # Width of the wordcloud border
    random_state=42,
).generate(neg_tweet)

# Plot the WordCloud
plt.figure(figsize=(12, 10))
plt.imshow(neg_wordcloud, interpolation="bilinear")
plt.title('Word Cloud - Negative Tweets', fontsize=16)
plt.axis("off")
plt.show()

# %% [markdown]
# Some words, like, "want", "think", "going" can be termed as neutral. Words like, "dont", "stupid", "hurt", "cant" etc. make sense as negative words.

# %% [markdown]
# <br>
# <span style="color: yellow; background-color: black; font-weight: bold; padding: 5px; font-size: 32px;"> Positive Tweets </span>
# </br>

# %%
positive_tweets = twitter_data[twitter_data['sentiment']==1]

# Concatenate positive tweets
pos_tweet = ' '.join(positive_tweets['text'].astype(str))

# Generate WordCloud with custom parameters
pos_wordcloud = WordCloud(
    width=1600,
    height=800,
    max_font_size=200,
    background_color='black',
    colormap='viridis',  # You can change the colormap
    contour_color='steelblue',  # Color of the wordcloud border
    contour_width=2,  # Width of the wordcloud border
    random_state=42,
).generate(pos_tweet)

# Plot the WordCloud
plt.figure(figsize=(12, 10))
plt.imshow(pos_wordcloud, interpolation="bilinear")
plt.title('Word Cloud - Positive Tweets', fontsize=16)
plt.axis("off")
plt.show()

# %% [markdown]
# In this wordcloud of positive tweets, neutral words, like "today", "tonight", "still", etc are present. Also, words like "thank", "haha", "awesome", "good", etc stand out as the positive words.
#
# Words like "day", "need", "will", "still", "work" etc are common in both the positive and negative tweets. Hence, it can be concluded that people have both positive and negative response towards work and their day.
#
# What I found surprising is the presence of "lol" and "love" in both the positive and the negative tweets wordclouds. So, now, I am going to inspect this.

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">DATA TRANSFORMATION</h2>
# </div>

# %%
vect = CountVectorizer()

# %%
#Tokenise and build vocab
vect.fit(twitter_data.text)
# Out:
# CountVectorizer()

# %%
len(vect.get_feature_names())
# Out:
# 118312

# %% [markdown]
# Hence, the corpus consists of 118312 different words.

# %%
#Encode document
neg_matrix = vect.transform(twitter_data[twitter_data.sentiment==0].text)
pos_matrix = vect.transform(twitter_data[twitter_data.sentiment==1].text)

# %%
neg_tf = np.sum(neg_matrix, axis=0)
pos_tf = np.sum(pos_matrix, axis=0)

# %%
#Remove single-dimensional entries from the shape of an array
neg = np.squeeze(np.asarray(neg_tf))
pos = np.squeeze(np.asarray(pos_tf))

# %%
term_freq_df = pd.DataFrame([neg, pos], columns = vect.get_feature_names()).transpose()

# %%
term_freq_df.head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_73116_row0_col0, #T_73116_row0_col1, #T_73116_row1_col0, #T_73116_row1_col1, #T_73116_row2_col0, #T_73116_row2_col1, #T_73116_row3_col0, #T_73116_row3_col1, #T_73116_row4_col0, #T_73116_row4_col1 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_73116">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73116_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_73116_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73116_level0_row0" class="row_heading level0 row0" >aa</th>
#       <td id="T_73116_row0_col0" class="data row0 col0" >45</td>
#       <td id="T_73116_row0_col1" class="data row0 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_73116_level0_row1" class="row_heading level0 row1" >aaa</th>
#       <td id="T_73116_row1_col0" class="data row1 col0" >23</td>
#       <td id="T_73116_row1_col1" class="data row1 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_73116_level0_row2" class="row_heading level0 row2" >aaaa</th>
#       <td id="T_73116_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_73116_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_73116_level0_row3" class="row_heading level0 row3" >aaaaa</th>
#       <td id="T_73116_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_73116_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_73116_level0_row4" class="row_heading level0 row4" >aaaaaa</th>
#       <td id="T_73116_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_73116_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#   </tbody>
# </table>

# %%
term_freq_df.columns = ['negative', 'positive']

# %%
term_freq_df['total'] = term_freq_df['negative'] + term_freq_df['positive']

# %%
term_freq_df.sort_values(by='total', ascending=False).head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_f43ed_row0_col0, #T_f43ed_row0_col1, #T_f43ed_row0_col2, #T_f43ed_row1_col0, #T_f43ed_row1_col1, #T_f43ed_row1_col2, #T_f43ed_row2_col0, #T_f43ed_row2_col1, #T_f43ed_row2_col2, #T_f43ed_row3_col0, #T_f43ed_row3_col1, #T_f43ed_row3_col2, #T_f43ed_row4_col0, #T_f43ed_row4_col1, #T_f43ed_row4_col2 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_f43ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f43ed_level0_col0" class="col_heading level0 col0" >negative</th>
#       <th id="T_f43ed_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_f43ed_level0_col2" class="col_heading level0 col2" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f43ed_level0_row0" class="row_heading level0 row0" >to</th>
#       <td id="T_f43ed_row0_col0" class="data row0 col0" >78026</td>
#       <td id="T_f43ed_row0_col1" class="data row0 col1" >63169</td>
#       <td id="T_f43ed_row0_col2" class="data row0 col2" >141195</td>
#     </tr>
#     <tr>
#       <th id="T_f43ed_level0_row1" class="row_heading level0 row1" >the</th>
#       <td id="T_f43ed_row1_col0" class="data row1 col0" >64676</td>
#       <td id="T_f43ed_row1_col1" class="data row1 col1" >66278</td>
#       <td id="T_f43ed_row1_col2" class="data row1 col2" >130954</td>
#     </tr>
#     <tr>
#       <th id="T_f43ed_level0_row2" class="row_heading level0 row2" >my</th>
#       <td id="T_f43ed_row2_col0" class="data row2 col0" >48048</td>
#       <td id="T_f43ed_row2_col1" class="data row2 col1" >31387</td>
#       <td id="T_f43ed_row2_col2" class="data row2 col2" >79435</td>
#     </tr>
#     <tr>
#       <th id="T_f43ed_level0_row3" class="row_heading level0 row3" >it</th>
#       <td id="T_f43ed_row3_col0" class="data row3 col0" >39520</td>
#       <td id="T_f43ed_row3_col1" class="data row3 col1" >36896</td>
#       <td id="T_f43ed_row3_col2" class="data row3 col2" >76416</td>
#     </tr>
#     <tr>
#       <th id="T_f43ed_level0_row4" class="row_heading level0 row4" >and</th>
#       <td id="T_f43ed_row4_col0" class="data row4 col0" >38529</td>
#       <td id="T_f43ed_row4_col1" class="data row4 col1" >37495</td>
#       <td id="T_f43ed_row4_col2" class="data row4 col2" >76024</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Assign a name to the index (which is now the first column)
term_freq_df = term_freq_df.rename_axis('word').reset_index()

# %%
term_freq_df.head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_9a72c_row0_col0, #T_9a72c_row0_col1, #T_9a72c_row0_col2, #T_9a72c_row0_col3, #T_9a72c_row1_col0, #T_9a72c_row1_col1, #T_9a72c_row1_col2, #T_9a72c_row1_col3, #T_9a72c_row2_col0, #T_9a72c_row2_col1, #T_9a72c_row2_col2, #T_9a72c_row2_col3, #T_9a72c_row3_col0, #T_9a72c_row3_col1, #T_9a72c_row3_col2, #T_9a72c_row3_col3, #T_9a72c_row4_col0, #T_9a72c_row4_col1, #T_9a72c_row4_col2, #T_9a72c_row4_col3 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_9a72c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a72c_level0_col0" class="col_heading level0 col0" >word</th>
#       <th id="T_9a72c_level0_col1" class="col_heading level0 col1" >negative</th>
#       <th id="T_9a72c_level0_col2" class="col_heading level0 col2" >positive</th>
#       <th id="T_9a72c_level0_col3" class="col_heading level0 col3" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a72c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a72c_row0_col0" class="data row0 col0" >aa</td>
#       <td id="T_9a72c_row0_col1" class="data row0 col1" >45</td>
#       <td id="T_9a72c_row0_col2" class="data row0 col2" >23</td>
#       <td id="T_9a72c_row0_col3" class="data row0 col3" >68</td>
#     </tr>
#     <tr>
#       <th id="T_9a72c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a72c_row1_col0" class="data row1 col0" >aaa</td>
#       <td id="T_9a72c_row1_col1" class="data row1 col1" >23</td>
#       <td id="T_9a72c_row1_col2" class="data row1 col2" >12</td>
#       <td id="T_9a72c_row1_col3" class="data row1 col3" >35</td>
#     </tr>
#     <tr>
#       <th id="T_9a72c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9a72c_row2_col0" class="data row2 col0" >aaaa</td>
#       <td id="T_9a72c_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_9a72c_row2_col2" class="data row2 col2" >6</td>
#       <td id="T_9a72c_row2_col3" class="data row2 col3" >16</td>
#     </tr>
#     <tr>
#       <th id="T_9a72c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9a72c_row3_col0" class="data row3 col0" >aaaaa</td>
#       <td id="T_9a72c_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_9a72c_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_9a72c_row3_col3" class="data row3 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_9a72c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9a72c_row4_col0" class="data row4 col0" >aaaaaa</td>
#       <td id="T_9a72c_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_9a72c_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_9a72c_row4_col3" class="data row4 col3" >9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="text-align: center; background-color: yellow; padding: 10px;">
#     <h2 style="font-weight: bold;">SAVING THE DATASET</h2>
# </div>

# %%
output_file_path = 'twitter_term_frequency_data.csv'

# %%
# Save the DataFrame to a CSV file
term_freq_df.to_csv(output_file_path, index=False)

# %%
print("DataFrame saved to:", output_file_path)
# Out:
# DataFrame saved to: twitter_term_frequency_data.csv
